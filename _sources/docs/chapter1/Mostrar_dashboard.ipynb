# %% [markdown]
# ## Dashboard
# Se muestra una imagen del dashboard, donde como se creo el paso a paso, tiene un filtro donde el usuario va poder filtrar por año, y va poder ver el promedio de las variables que elegimos y las graficas

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img = mpimg.imread('imagen_dash.png')

imgplot = plt.imshow(img)
plt.axis('off')  # Ocultar los ejes
plt.show()
